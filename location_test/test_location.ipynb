# %%
from stixpy.product import Product
from astropy import units as u 
from stx_estimate_flare_location import stx_estimate_flare_location

# %%
cpd_sci = Product('solo_L1_stix-sci-xray-cpd_20220331T181321-20220331T183413_V02_2203310588-65252.fits')

# %%
time_range = ['2022-03-31 18:22:00', '2022-03-31 18:23:00'] 
energy_range = [5,10]*u.keV

# %%
max_stix, max_hpc, sidelobes_ratio = stx_estimate_flare_location(cpd_sci, time_range, energy_range, plot=False)

# %%
print(max_stix)
