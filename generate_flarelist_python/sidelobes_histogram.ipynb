# %% [markdown]
# Notebook for visualizing the collected flares to see the distribution of the sidelobes ratios.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# load data
df = pd.read_csv("stix_flarelist_w_locations_20241001_20241001.csv")

# %%
fig, ax = plt.subplots(figsize=(6,4))
_ = sns.histplot(data=df,x="sidelobes_ratio", ax=ax)

# below histogram is for a small flarelist consisting of 77 flares

# %%
# Newely parsed data with raw counts:
df = pd.read_csv("../stix_flarelist_w_locations_20240901_20240909.csv")

# %%
fig, ax = plt.subplots(figsize=(6,4))
_ = sns.histplot(data=df, x="sidelobes_ratio", ax=ax)

# %%
# Plot dataset with 25219 flares 
df = pd.read_csv("../STIX_flarelist_w_locations_20210214_20250228_version1_python.csv")

# %%
fig, ax = plt.subplots(figsize=(6,4))
_ = sns.histplot(data=df, x="sidelobes_ratio", ax=ax)
